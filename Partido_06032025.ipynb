# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
import functions

# %%
path ='data/Partido_06032025_QuimsavsIACC_visitante.csv'
df = pd.read_csv(path)

# %%
titulo = '06/03/2025 Quimsa vs Instituto'
functions.puntos_por_partido(df, titulo)
functions.por_partido(df, titulo)
