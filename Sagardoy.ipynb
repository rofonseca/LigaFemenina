# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
import functions

# %%
path = "data/Sagardoy.csv" 
df = pd.read_csv(path)

# %%
df.head()
# Out:
#        Jugadora               Fecha    Min  Puntos  FG  FGA  2P  2PA  3P  3PA  \
# 0  Sagardoy, M.     6 de Marzo 2025  28:03       9   6    3   6    3   0    0
# 1  Sagardoy, M.     6 de Marzo 2025  28:03       9   6    3   6    3   0    0
# 2  Sagardoy, M.     1 de Marzo 2025  17:25       6   4    3   4    3   0    0
# 3  Sagardoy, M.  23 de Febrero 2025  25:39       3   4    1   4    1   0    0
#
#    FT  FTA  ORB  DRB  REB  AST  FP  TOV  ROB  TAP
# 0   5    3    4    6   10    2   1    2    1    3
# 1   5    3    4    6   10    2   1    2    1    3
# 2   2    0    5    2    7    1   1    1    1    0
# 3   2    1    3    3    6    2   1    1    0    0

# %%
functions.por_jugador(df, 'Sagardoy, M.')
